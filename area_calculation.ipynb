# %% [markdown]
# # Calculating the area of a loop
#
# This notebook demonstrates the different ways of calculating areas of a loop.
# The script `generate_fake_loop.py` was used to generate a loop with artificial noise and missingness from parametric equation:
#
# $$
# \begin{align}
# x & = \cos(\theta) + \sin(\theta)\\
# y & = \sin(\theta)
# \end{align}
# $$
#
# where $\theta$ is in the range $[0, 2\pi]$

# %% [markdown]
# ## Imports

# %%
import numpy
import matplotlib.pyplot as plt
